# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

newimage = cv2.imread('bind.webp')
oldimage = cv2.cvtColor(newimage,cv2.COLOR_BGR2RGB)
image = cv2.resize(oldimage,(1000,1000))

siteB = np.array([[120,150],[520,150],[520,900],[120,900]])
siteA = np.array([[530,150],[900,150],[900,900],[530,900]])
cv2.drawContours(image,[siteB], -1, (0,255,0), 2)
cv2.putText(image,text = 'Bomb Site B', org = (250,335), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (0,255,0),thickness = 2,lineType = cv2.LINE_AA)
cv2.drawContours(image,[siteA], -1, (255,0,0), 2)
cv2.putText(image,text = 'Bomb Site A', org = (735,360), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (255,0,0),thickness = 2,lineType = cv2.LINE_AA)
#cv2.imshow('Contours',image)

plt.imshow(image)


df = pd.read_csv('skillsAnchor_Bind.csv')
xloc = np.array(df['locX'])
yloc = np.array(df['locY'])
r= np.array(df['round'])
time = np.array(df['TimeMillis'])
plt.scatter(xloc,yloc)
#print(len(r))
x = 0
y = 0
T = []
for i in range(1,13):
    print(i)
    df1 = (df.loc[df['round'] == i])
    #print(df1)
    y = len(df1)
    if(y == 1):
        print(time[x])
        continue
    for j in range(x,x+y):
        #print(j)
        if(((cv2.pointPolygonTest(siteB,(xloc[x],yloc[x]),False) != -1) == True) and ((cv2.pointPolygonTest(siteB,(xloc[j],yloc[j]),False) != -1) == False)):
            z = j
            break
        if(((cv2.pointPolygonTest(siteA,(xloc[x],yloc[x]),False) != -1) == True) and ((cv2.pointPolygonTest(siteA,(xloc[j],yloc[j]),False) != -1) == False)):
            z = j
            break    
    if(((cv2.pointPolygonTest(siteA,(xloc[x],yloc[x]),False) != -1) == True) and ((cv2.pointPolygonTest(siteA,(xloc[x+y-1],yloc[x+y-1]),False) != -1) == True)):
        print(time[x+y-1] - time[x])
    elif(((cv2.pointPolygonTest(siteB,(xloc[x],yloc[x]),False) != -1) == True) and ((cv2.pointPolygonTest(siteB,(xloc[x+y-1],yloc[x+y-1]),False) != -1) == True)):
        print(time[x+y-1] - time[x])
    else:
        print(time[z]- time[x])
        
    x = x+y
plt.show()
# Out:
# 1
# 8569
# 2
# 57842
# 3
# 14011
# 4
# 23108
# 5
# 59795
# 6
# 13100
# 7
# 20108
# 8
# 13380
# 9
# 16300
# 10
# 6992
# 11
# 26573
# 12
# 60244

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

newimage = cv2.imread('bind.webp')
oldimage = cv2.cvtColor(newimage,cv2.COLOR_BGR2RGB)
image = cv2.resize(oldimage,(1000,1000))

siteB = np.array([[120,150],[520,150],[520,900],[120,900]])
siteA = np.array([[530,150],[900,150],[900,900],[530,900]])
cv2.drawContours(image,[siteB], -1, (0,255,0), 2)
cv2.putText(image,text = 'Bomb Site B', org = (250,335), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (0,255,0),thickness = 2,lineType = cv2.LINE_AA)
cv2.drawContours(image,[siteA], -1, (255,0,0), 2)
cv2.putText(image,text = 'Bomb Site A', org = (735,360), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (255,0,0),thickness = 2,lineType = cv2.LINE_AA)
#cv2.imshow('Contours',image)

#plt.imshow(image)

df = pd.read_csv('skillsAnchor_Bind.csv')
xloc = np.array(df['locX'])
yloc = np.array(df['locY'])
r= np.array(df['round'])
time = np.array(df['TimeMillis'])
#print(len(r))
x = 0
y = 0
T = []
for i in range(1,13):
    print(i)
    df1 = (df.loc[df['round'] == i])
    print(df1)
    y = len(df1)
    if(y == 1):
        print(time[x])
        x = x+1
        continue
    for j in range(x,x+y):
        #print(j)
        if((cv2.pointPolygonTest(siteB,(xloc[j],yloc[j]),False) != -1) == True):
            print('A site')
        else:
            print('B site')
    x = x+y
#plt.show()
# Out:
# 1
#    round  TimeMillis        locX        locY
# 0      1       26673  697.596202  332.480950
# 1      1       28357  713.882967  320.569733
# 2      1       28759  713.943739  324.276795
# 3      1       30734  703.855668  322.149792
# 4      1       32274  707.015786  327.254599
# 5      1       35242  734.788368  347.126884
# B site
# B site
# B site
# B site
# B site
# B site
# 2
#     round  TimeMillis        locX        locY
# 6       2       44063  804.979466  336.431098
# 7       2       47562  803.946350  362.927478
# 8       2       63718  805.647952  348.767715
# 9       2       65637  804.918694  372.347062
# 10      2       74402  633.968427  341.110504
# 11      2       75570  606.864332  344.635252
# 12      2       77066  593.190742  366.573769
# 13      2      101905  290.730920  289.150861
# B site
# B site
# B site
# B site
# B site
# B site
# B site
# A site
# 3
#     round  TimeMillis        locX        locY
# 14      3       57916  251.958694  324.762967
# 15      3       63247  316.254955  216.893531
# 16      3       63959  312.122493  216.225044
# 17      3       64440  329.685460  213.976498
# 18      3       71927  618.228605  224.003798
# 19      3       80847  659.431691  336.795727
# A site
# A site
# A site
# A site
# B site
# B site
# 4
#     round  TimeMillis        locX        locY
# 20      4       13862  321.724392  458.156439
# 21      4       16124  320.205104  426.008309
# 22      4       25668  330.657804  344.088309
# 23      4       36970  626.736617  250.014006
# 24      4       49094  672.740653  316.984214
# 25      4       52058  711.512878  320.326647
# 26      4       53912  727.070386  347.491513
# 27      4       56617  730.595133  348.706944
# A site
# A site
# A site
# B site
# B site
# B site
# B site
# B site
# 5
#     round  TimeMillis        locX        locY
# 28      5        6117  309.509318  390.700059
# 29      5       24019  245.881543  397.749555
# 30      5       59219  272.134837  274.687240
# 31      5       65912  239.622077  297.598101
# A site
# A site
# A site
# A site
# 6
#     round  TimeMillis        locX        locY
# 32      6       55423  843.873234  466.542908
# 33      6       56160  842.657804  461.012700
# 34      6       57225  831.293531  438.162611
# 35      6       60003  761.345519  365.966053
# 36      6       68523  451.653887  455.907893
# B site
# B site
# B site
# B site
# A site
# 7
#     round  TimeMillis        locX        locY
# 37      7       27249  340.745875  459.432641
# 38      7       28775  372.103976  461.802730
# 39      7       37256  453.598576  619.504807
# 40      7       47357  621.388724  492.978516
# 41      7       51023  605.709674  477.724867
# 42      7       61542  633.846884  394.103264
# 43      7       64848  737.826944  388.998457
# 44      7       65060  747.732700  389.484629
# A site
# A site
# A site
# B site
# B site
# B site
# B site
# B site
# 8
#     round  TimeMillis        locX        locY
# 45      8       21753  221.998338  431.660059
# 46      8       33122  248.373175  456.211751
# 47      8       35133  276.571157  423.273591
# A site
# A site
# A site
# 9
#     round  TimeMillis        locX        locY
# 48      9       27539  859.187656  422.969733
# 49      9       28212  846.729495  422.787418
# 50      9       36557  796.653768  392.158576
# 51      9       38263  777.146113  381.827418
# 52      9       43839  704.888783  354.541009
# B site
# B site
# B site
# B site
# B site
# 10
#     round  TimeMillis        locX        locY
# 53     10        6992  781.339347  407.351454
# 6992
# 11
#     round  TimeMillis        locX        locY
# 54     11       30862  653.719169  506.287478
# 55     11       32477  641.078694  538.192522
# 56     11       33565  648.249733  523.911217
# 57     11       35038  644.968071  520.082611
# B site
# B site
# B site
# B site
# 12
#     round  TimeMillis        locX        locY
# 58     12        4682  305.133768  418.290326
# 59     12       30031  329.442374  373.258635
# 60     12       66535  344.088309  250.804036
# 61     12       95282  718.744688  357.761899
# 62     12       99468  620.781009  380.186587
# A site
# A site
# A site
# B site
# B site

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

newimage = cv2.imread('bind.webp')
oldimage = cv2.cvtColor(newimage,cv2.COLOR_BGR2RGB)
image = cv2.resize(oldimage,(1000,1000))

siteB = np.array([[120,150],[520,150],[520,900],[120,900]])
siteA = np.array([[530,150],[900,150],[900,900],[530,900]])
cv2.drawContours(image,[siteB], -1, (0,255,0), 2)
cv2.putText(image,text = 'Bomb Site B', org = (250,335), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (0,255,0),thickness = 2,lineType = cv2.LINE_AA)
cv2.drawContours(image,[siteA], -1, (255,0,0), 2)
cv2.putText(image,text = 'Bomb Site A', org = (735,360), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (255,0,0),thickness = 2,lineType = cv2.LINE_AA)
#cv2.imshow('Contours',image)

#plt.imshow(image)

df = pd.read_csv('skillsAnchor_Bind.csv')
xloc = np.array(df['locX'])
yloc = np.array(df['locY'])
r= np.array(df['round'])
time = np.array(df['TimeMillis'])
#print(len(r))
x = 0
y = 0
z = 0
T = []
for i in range(1,13):
    #print(i)
    df1 = (df.loc[df['round'] == i])
    #print(df1)
    y = len(df1)
    #print('x',x)
    #print('x+y',x+y-1)
    if(y == 1):
        T.append(time[x]) #append1
        x = x+y
        continue
    if(((cv2.pointPolygonTest(siteB,(xloc[x],yloc[x]),False) != -1) == True) and (cv2.pointPolygonTest(siteB,(xloc[x+1],yloc[x+1]),False) != -1) == False):
        T.append(time[x]) #append2
        x = x+y
        continue
    if(((cv2.pointPolygonTest(siteA,(xloc[x],yloc[x]),False) != -1) == True) and (cv2.pointPolygonTest(siteA,(xloc[x+1],yloc[x+1]),False) != -1) == False):
        T.append(time[x]) #append3
        x = x+y
        continue
    for j in range(x,x+y):
        #print(j)
        if(((cv2.pointPolygonTest(siteB,(xloc[x],yloc[x]),False) != -1) == True) and ((cv2.pointPolygonTest(siteB,(xloc[j],yloc[j]),False) != -1) == False)):
            z = j-1
            break
        elif(((cv2.pointPolygonTest(siteA,(xloc[x],yloc[x]),False) != -1) == True) and ((cv2.pointPolygonTest(siteA,(xloc[j],yloc[j]),False) != -1) == False)):
            z = j-1
            break    
        elif(((cv2.pointPolygonTest(siteA,(xloc[x],yloc[x]),False) != -1) == True) and ((cv2.pointPolygonTest(siteA,(xloc[x+y-1],yloc[x+y-1]),False) != -1) == True)):
            z = x+y-1
            break
        elif(((cv2.pointPolygonTest(siteB,(xloc[x],yloc[x]),False) != -1) == True) and ((cv2.pointPolygonTest(siteB,(xloc[x+y-1],yloc[x+y-1]),False) != -1) == True)):
            z = x+y-1
            break
    #print('z = ',z)
    T.append(time[z])
        
    x = x+y
T = np.array(T)
T = ((T/(1000)))
print(T.shape)
anchor = round(np.average(T),2)
print(anchor)
y = np.arange(1,13,1)
fig = plt.figure(figsize = (18,9),facecolor = '#fff3d1')
ax = plt.axes()
ax.set_facecolor('#fff3d1')
plt.grid(color = '#a3a3a3', linestyle='--',linewidth=0.2)
plt.ylim([0,80])
plt.plot(y,T,label = 'Round Anchor Time')
plt.hlines(anchor,xmin = 1,xmax = 12,color = 'red',linestyle = ':',label = 'Average Anchor Time')
plt.annotate(f'Avg. Anchor Time = {anchor}s', (10.1,70),size = 14)
plt.title('GE Skillz || Site Anchor Time || BIND',size = 18)
plt.xlabel('Round number ->',size = 16)
plt.ylabel('Time [s] ->',size = 16)

plt.legend(fontsize = '12')
plt.savefig('GESkillzAnchorTime.png',dpi = 600,bbox_inches = 'tight',facecolor = 'auto')
plt.show()
# Out:
# (12,)
# 46.09

# %%
print(cv2.pointPolygonTest(siteA,(xloc[59],yloc[59]),False) != -1)
print(xloc[59],',',yloc[59])
# Out:
# False
# 329.4423739 , 373.258635

# %%
x = 58
y = 0
z = 0
T = []

df1 = (df.loc[df['round'] == 12])
print(df1)
y = len(df1)
if(((cv2.pointPolygonTest(siteB,(xloc[x],yloc[x]),False) != -1) == True) and (cv2.pointPolygonTest(siteB,(xloc[x+1],yloc[x+1]),False) != -1) == False):
    print(time[x])
    x = x+y
if(((cv2.pointPolygonTest(siteA,(xloc[x],yloc[x]),False) != -1) == True) and (cv2.pointPolygonTest(siteA,(xloc[x+1],yloc[x+1]),False) != -1) == False):
    print(time[x])
    x = x+y

x = x+y
# Out:
#     round  TimeMillis        locX        locY
# 58     12        4682  305.133768  418.290326
# 59     12       30031  329.442374  373.258635
# 60     12       66535  344.088309  250.804036
# 61     12       95282  718.744688  357.761899
# 62     12       99468  620.781009  380.186587
