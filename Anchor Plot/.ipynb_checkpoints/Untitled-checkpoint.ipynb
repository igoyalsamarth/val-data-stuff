# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#--------------ASCENT MAP---------------------#
newimage = cv2.imread('ascent.png')
oldimage = cv2.cvtColor(newimage,cv2.COLOR_BGR2RGB)
image = cv2.resize(oldimage,(1000,1000))
siteB = np.array([[80,30],[595,30],[595,420],[573,420],[573,640],[537,640],[537,900],[80,900]])
siteA = np.array([[597,30],[970,30],[970,900],[539,900],[539,642],[575,642],[575,422],[597,422]])
cv2.drawContours(image,[siteB], -1, (0,255,0), 2)
cv2.putText(image,text = 'Bomb Site B', org = (250,335), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (0,255,0),thickness = 2,lineType = cv2.LINE_AA)
cv2.drawContours(image,[siteA], -1, (255,0,0), 2)
cv2.putText(image,text = 'Bomb Site A', org = (735,360), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (255,0,0),thickness = 2,lineType = cv2.LINE_AA)
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 999.5, 999.5, -0.5)

# %%
#--------------SPLIT MAP---------------------#
newimage = cv2.imread('split.webp')
oldimage = cv2.cvtColor(newimage,cv2.COLOR_BGR2RGB)
oimage = cv2.resize(oldimage,(1000,1000))
image = cv2.rotate(oimage, cv2.ROTATE_90_CLOCKWISE)
siteB = np.array([[20,30],[485,30],[485,320],[550,320],[550,585],[497,585],[497,950],[20,950]])
siteA = np.array([[487,30],[970,30],[970,950],[499,950],[499,587],[552,587],[552,318],[487,318]])
cv2.drawContours(image,[siteB], -1, (0,255,0), 2)
cv2.putText(image,text = 'Bomb Site B', org = (250,335), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (0,255,0),thickness = 2,lineType = cv2.LINE_AA)
cv2.drawContours(image,[siteA], -1, (255,0,0), 2)
cv2.putText(image,text = 'Bomb Site A', org = (735,360), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (255,0,0),thickness = 2,lineType = cv2.LINE_AA)
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 999.5, 999.5, -0.5)

# %%
#--------------ICEBOX MAP---------------------#
newimage = cv2.imread('icebox.webp')
oldimage = cv2.cvtColor(newimage,cv2.COLOR_BGR2RGB)
oimage = cv2.resize(oldimage,(1000,1000))
image = cv2.rotate(oimage, cv2.ROTATE_90_COUNTERCLOCKWISE)
siteB = np.array([[50,0],[510,0],[510,325],[484,325],[484,527],[458,527],[458,557],[465,557],[465,655],[560,655],[560,950],[50,950]])
siteA = np.array([[512,0],[950,0],[950,950],[562,950],[562,653],[486,653],[486,554],[460,554],[460,529],[486,529],[486,327],[512,327]])
cv2.drawContours(image,[siteB], -1, (0,255,0), 2)
cv2.putText(image,text = 'Bomb Site B', org = (250,335), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (0,255,0),thickness = 2,lineType = cv2.LINE_AA)
cv2.drawContours(image,[siteA], -1, (255,0,0), 2)
cv2.putText(image,text = 'Bomb Site A', org = (735,360), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (255,0,0),thickness = 2,lineType = cv2.LINE_AA)
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 999.5, 999.5, -0.5)

# %%
#--------------FRACTURE MAP---------------------#
newimage = cv2.imread('fracture.webp')
oldimage = cv2.cvtColor(newimage,cv2.COLOR_BGR2RGB)
image = cv2.resize(oldimage,(1000,1000))
siteB = np.array([[0,0],[495,0],[495,400],[485,400],[485,730],[550,730],[550,842],[440,842],[440,950],[0,950]])
siteA = np.array([[497,0],[950,0],[950,950],[442,950],[442,844],[552,844],[552,728],[487,728],[487,402],[497,402],[497,0]])
cv2.drawContours(image,[siteB], -1, (0,255,0), 2)
cv2.putText(image,text = 'Bomb Site B', org = (250,335), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (0,255,0),thickness = 2,lineType = cv2.LINE_AA)
cv2.drawContours(image,[siteA], -1, (255,0,0), 2)
cv2.putText(image,text = 'Bomb Site A', org = (735,360), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (255,0,0),thickness = 2,lineType = cv2.LINE_AA)
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 999.5, 999.5, -0.5)

# %%
#--------------PEARL MAP-----------------#
newimage = cv2.imread('pearl.webp')
oldimage = cv2.cvtColor(newimage,cv2.COLOR_BGR2RGB)
image = cv2.resize(oldimage,(1000,1000))
siteB = np.array([[0,0],[565,0],[565,372],[572,372],[572,500],[545,500],[545,980],[0,980]])
siteA = np.array([[567,0],[1000,0],[1000,980],[547,980],[547,502],[574,502],[574,370],[567,370]])
cv2.drawContours(image,[siteB], -1, (0,255,0), 2)
cv2.putText(image,text = 'Bomb Site B', org = (250,335), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (0,255,0),thickness = 2,lineType = cv2.LINE_AA)
cv2.drawContours(image,[siteA], -1, (255,0,0), 2)
cv2.putText(image,text = 'Bomb Site A', org = (735,360), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (255,0,0),thickness = 2,lineType = cv2.LINE_AA)
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 999.5, 999.5, -0.5)

# %%
#--------------BIND MAP--------------------#
newimage = cv2.imread('bind.webp')
oldimage = cv2.cvtColor(newimage,cv2.COLOR_BGR2RGB)
image = cv2.resize(oldimage,(1000,1000))
siteB = np.array([[120,0],[520,0],[520,480],[500,480],[500,580],[550,580],[550,980],[120,980]])
siteA = np.array([[522,0],[950,0],[950,980],[552,980],[552,578],[502,578],[502,482],[522,482]])
cv2.drawContours(image,[siteB], -1, (0,255,0), 2)
cv2.putText(image,text = 'Bomb Site B', org = (250,335), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (0,255,0),thickness = 2,lineType = cv2.LINE_AA)
cv2.drawContours(image,[siteA], -1, (255,0,0), 2)
cv2.putText(image,text = 'Bomb Site A', org = (735,360), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (255,0,0),thickness = 2,lineType = cv2.LINE_AA)
plt.imshow(image)
plt.axis("off")
# Out:
# (-0.5, 999.5, 999.5, -0.5)

# %%
#--------------HAVEN MAP---------------------#
newimage = cv2.imread('haven.webp')
oldimage = cv2.cvtColor(newimage,cv2.COLOR_BGR2RGB)
oimage = cv2.resize(oldimage,(1000,1000))
image = cv2.rotate(oimage, cv2.ROTATE_90_CLOCKWISE)
siteC = np.array([[50,100],[533,100],[533,258],[363,258],[363,402],[413,402],[413,583],[438,583],[438,713],[358,713],[358,810],[50,810]])
siteB = np.array([[365,330],[400,330],[400,260],[653,260],[653,438],[578,438],[578,578],[573,578],[573,850],[580,850],[580,980],[360,980],[360,715],[440,715],[440,580],[415,580],[415,400],[365,400]])
siteA = np.array([[535,30],[970,30],[970,800],[575,800],[575,580],[580,580],[580,440],[655,440],[655,258],[535,258]])
cv2.drawContours(image,[siteC], -1, (0,0,255), 2)
cv2.putText(image,text = 'Bomb Site C', org = (120,355), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (0,0,255),thickness = 2,lineType = cv2.LINE_AA)
cv2.drawContours(image,[siteB], -1, (0,255,0), 2)
cv2.putText(image,text = 'Bomb Site B', org = (450,435), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (0,255,0),thickness = 2,lineType = cv2.LINE_AA)
cv2.drawContours(image,[siteA], -1, (255,0,0), 2)
cv2.putText(image,text = 'Bomb Site A', org = (735,360), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (255,0,0),thickness = 2,lineType = cv2.LINE_AA)
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 999.5, 999.5, -0.5)

# %%
#--------------LOTUS MAP---------------------#
newimage = cv2.imread('lotus.webp')
oldimage = cv2.cvtColor(newimage,cv2.COLOR_BGR2RGB)
image = cv2.resize(oldimage,(1000,1000))
siteC = np.array([[40,100],[550,100],[550,300],[418,300],[418,406],[338,406],[338,597],[428,597],[428,717],[448,717],[448,900],[40,900]])
siteB = np.array([[420,408],[420,302],[655,302],[655,508],[590,508],[590,900],[450,900],[450,715],[430,715],[430,595],[340,595],[340,408]])
siteA = np.array([[552,100],[970,100],[970,800],[592,800],[592,510],[657,510],[657,300],[552,300]])
cv2.drawContours(image,[siteC], -1, (0,0,255), 2)
cv2.putText(image,text = 'Bomb Site C', org = (120,455), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (0,0,255),thickness = 2,lineType = cv2.LINE_AA)
cv2.drawContours(image,[siteB], -1, (0,255,0), 2)
cv2.putText(image,text = 'Bomb Site B', org = (450,435), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (0,255,0),thickness = 2,lineType = cv2.LINE_AA)
cv2.drawContours(image,[siteA], -1, (255,0,0), 2)
cv2.putText(image,text = 'Bomb Site A', org = (800,320), fontFace = cv2.FONT_HERSHEY_SIMPLEX,fontScale = 0.5, color = (255,0,0),thickness = 2,lineType = cv2.LINE_AA)
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 999.5, 999.5, -0.5)

# %%
matchMap = 'Bind'
matchId = 86365
playerId = 2829
playerName = 'GE skillZ'
opponentTeam = 'VLT'
startRound = 1
endRound = 12
defTeamId = []
plotTime = []
aR = []

# %%
df = pd.read_csv('loc.csv')
df = df[(df.matchId == matchId) & (df.playerId == playerId) & (df.roundNumber >= startRound) & (df.roundNumber <= endRound)]
df.reset_index(inplace = True)
df = df[['roundNumber', 'playerId', 'roundTimeMillis', 'locationX','locationY', 'matchId']]
print(df)
#X = np.array(df['locationX'])
#Y = np.array(df['locationY'])
#plt.imshow(image)
#plt.scatter(X,Y)
# Out:
#     roundNumber  playerId  roundTimeMillis   locationX   locationY  matchId
# 0             1      2829            23245  596.776261  344.149080    86365
# 1             1      2829            66223  302.095193  558.672522    86365
# 2             1      2829            67866  251.472522  560.313353    86365
# 3             1      2829            72755  210.026350  459.007240    86365
# 4             1      2829            74566  227.832404  444.604392    86365
# 5             1      2829            75248  227.832404  444.604392    86365
# 6             1      2829            79938  254.511098  402.185875    86365
# 7             2      2829            36440  597.687834  337.707300    86365
# 8             2      2829            79187  638.283205  376.783383    86365
# 9             3      2829            65930  628.620534  340.198932    86365
# 10            3      2829            67497  652.139110  338.436558    86365
# 11            3      2829            68965  621.814125  334.243323    86365
# 12            3      2829            72634  652.139110  316.011869    86365
# 13            4      2829             5903  642.354896  338.436558    86365
# 14            5      2829            12216  654.205341  329.260059    86365
# 15            5      2829            13289  666.724273  315.464926    86365
# 16            5      2829            14638  689.999763  302.581365    86365
# 17            6      2829            10778  672.132938  285.869199    86365
# 18            7      2829            15077  802.670148  326.707656    86365
# 19            7      2829            27169  787.659585  306.956914    86365
# 20            7      2829            30184  740.136261  299.056617    86365
# 21            7      2829            32952  702.518694  303.918338    86365
# 22            7      2829            33129  699.783976  305.984570    86365
# 23            7      2829            62706  617.317033  527.132107    86365
# 24            8      2829             9267  770.400475  401.213531    86365
# 25            9      2829            16660  459.007240  202.004510    86365
# 26            9      2829            16945  449.040712  204.253056    86365
# 27            9      2829            25787  493.100059  184.137685    86365
# 28            9      2829            31291  374.109436  209.783264    86365
# 29            9      2829            33862  332.845579  243.815312    86365
# 30            9      2829            38597  327.558457  264.234540    86365
# 31           10      2829            14134  730.959763  329.807003    86365
# 32           10      2829            17917  773.256736  314.310267    86365
# 33           10      2829            21886  780.731632  339.105045    86365
# 34           10      2829            22139  785.350267  339.591217    86365
# 35           10      2829            22316  788.753472  340.624332    86365
# 36           11      2829            19917  596.168546  199.330564    86365
# 37           11      2829            20444  615.250801  199.391335    86365
# 38           11      2829            44157  775.079881  342.933650    86365
# 39           11      2829            44927  760.069318  353.082493    86365
# 40           11      2829            53510  707.562730  357.761899    86365
# 41           11      2829            53557  707.562730  357.761899    86365
# 42           12      2829            15009  674.138398  269.157033    86365
# 43           12      2829            16933  665.751929  302.155964    86365
# 44           12      2829            18970  662.895668  317.348843    86365
# 45           12      2829            25971  659.492463  304.404510    86365
# 46           12      2829            26264  659.492463  304.404510    86365
# 47           12      2829            27688  661.862552  298.813531    86365
# 48           12      2829            37084  659.188605  335.397982    86365
# 49           12      2829            51320  586.262789  373.137092    86365

# %%
xloc = np.array(df['locationX'])
yloc = np.array(df['locationY'])
r= np.array(df['roundNumber'])
time = np.array(df['roundTimeMillis'])
#print(len(r))
x = 0
y = 0
z = 0
T = []
for i in range(startRound,max(r)+1):
    #print(i)
    df1 = (df.loc[df['roundNumber'] == i])
    #print(df1)
    y = len(df1)
    if(y == 1):
        T.append(time[x]) #append1
        x = x+y
        continue
    if(((cv2.pointPolygonTest(siteB,(xloc[x],yloc[x]),False) != -1) == True) and (cv2.pointPolygonTest(siteB,(xloc[x+1],yloc[x+1]),False) != -1) == False):
        T.append(time[x]) #append2
        x = x+y
        continue
    if(((cv2.pointPolygonTest(siteA,(xloc[x],yloc[x]),False) != -1) == True) and (cv2.pointPolygonTest(siteA,(xloc[x+1],yloc[x+1]),False) != -1) == False):
        T.append(time[x]) #append3
        x = x+y
        continue
    for j in range(x,x+y):
        #print(j)
        if(((cv2.pointPolygonTest(siteB,(xloc[x],yloc[x]),False) != -1) == True) and ((cv2.pointPolygonTest(siteB,(xloc[j],yloc[j]),False) != -1) == False)):
            z = j-1
            break
        elif(((cv2.pointPolygonTest(siteA,(xloc[x],yloc[x]),False) != -1) == True) and ((cv2.pointPolygonTest(siteA,(xloc[j],yloc[j]),False) != -1) == False)):
            z = j-1
            break    
        elif(((cv2.pointPolygonTest(siteA,(xloc[x],yloc[x]),False) != -1) == True) and ((cv2.pointPolygonTest(siteA,(xloc[x+y-1],yloc[x+y-1]),False) != -1) == True)):
            z = x+y-1
            break
        elif(((cv2.pointPolygonTest(siteB,(xloc[x],yloc[x]),False) != -1) == True) and ((cv2.pointPolygonTest(siteB,(xloc[x+y-1],yloc[x+y-1]),False) != -1) == True)):
            z = x+y-1
            break
    T.append(time[z])
        
    x = x+y
T = np.array(T)
T = (T/(1000))
#print(T.shape)
anchor = round(np.average(T),2)
print(T)
print(anchor)
# Out:
# [23.245 79.187 72.634  5.903 14.638 10.778 62.706  9.267 38.597 22.316
#  53.557 51.32 ]
# 37.01

# %%
df2 = pd.read_csv('round.csv')
teamsId = np.unique(df2['attackingTeamId'])
df2 = df2[(df2.matchId == matchId) & (df2.roundNumber >= startRound) & (df2.roundNumber <= endRound)]
df2.reset_index(inplace = True)
df2 = df2[['roundNumber', 'matchId', 'winCondition', 'winningTeamId', 'spikePlant', 'spikePlantRoundTimeMillis','roundDurationMillis','attackingTeamId']]
print(df2)
atkTeam = np.unique(df2['attackingTeamId'])
for i in teamsId:
    if i != atkTeam:
        defTeamId.append(i)
print(defTeamId)
# Out:
#     roundNumber  matchId winCondition  winningTeamId spikePlant  \
# 0             1    86365        kills            363        NaN
# 1             2    86365         time            363        NaN
# 2             3    86365        kills            212   POST-WIN
# 3             4    86365         bomb            212       True
# 4             5    86365        kills            212       True
# 5             6    86365       defuse            363       True
# 6             7    86365        kills            363        NaN
# 7             8    86365         bomb            212       True
# 8             9    86365        kills            212   POST-WIN
# 9            10    86365        kills            212       True
# 10           11    86365        kills            212       True
# 11           12    86365        kills            363        NaN
#
#     spikePlantRoundTimeMillis  roundDurationMillis  attackingTeamId
# 0                         NaN                79938              212
# 1                         NaN               100000              212
# 2                     93243.0                93243              212
# 3                     27710.0                27710              212
# 4                     22212.0                55281              212
# 5                     19216.0                58528              212
# 6                         NaN                62706              212
# 7                     32217.0                32217              212
# 8                     83617.0                83617              212
# 9                     43406.0                63881              212
# 10                    20444.0                57066              212
# 11                        NaN                51320              212
# [363]

# %%
roundTime = np.array(df2['roundDurationMillis'])
plantTime = np.array(df2['spikePlantRoundTimeMillis'])
spikePlant = np.array(df2['spikePlant'])
winningTeamId = np.array(df2['winningTeamId'])
#print(roundTime)
rT = ((roundTime/(1000)))
pT = ((plantTime/1000))

for i in range(len(df2)):
    if(np.isnan(pT[i])):
        plotTime.append(rT[i])
    else:
        plotTime.append(pT[i])

aR = T/plotTime

#print(T)
#print(pT)
#print(aR)
#print(T/rT)
for i in range(len(aR)):
    if aR[i] > 1:
        aR[i] = 1.0
print(aR)
print(spikePlant)
# Out:
# [0.29078786 0.79187    0.77897537 0.21302779 0.65901315 0.56088676
#  1.         0.28764317 0.46159274 0.51412247 1.         1.        ]
# [nan nan 'POST-WIN' 'True' 'True' 'True' nan 'True' 'POST-WIN' 'True'
#  'True' nan]

# %%
#print(rT)
#print(pT)
print(aR)
print(plotTime)
print(T)
# Out:
# [0.29078786 0.79187    0.77897537 0.21302779 0.65901315 0.56088676
#  1.         0.28764317 0.46159274 0.51412247 1.         1.        ]
# [79.938, 100.0, 93.243, 27.71, 22.212, 19.216, 62.706, 32.217, 83.617, 43.406, 20.444, 51.32]
# [23.245 79.187 72.634  5.903 14.638 10.778 62.706  9.267 38.597 22.316
#  53.557 51.32 ]

# %%
y= np.arange(startRound,endRound+1,1)
fig = plt.figure(figsize = (18,9),facecolor = '#fff3d1')
ax = plt.axes()
ax.set_facecolor('#fff3d1')
plt.grid(color = '#a3a3a3', linestyle='--',linewidth=0.15)
plt.plot(y,plotTime, color = '#eb34c3', label = 'Round Objective Time')
plt.plot(y,T, label = 'Round Anchor Time')
plt.plot(y,rT,color= '#deb500', label = 'Total Round Time')
#plt.hlines(np.average(plotTime),xmin = startRound,xmax = endRound,color = '#eb34c3',linestyle = ':',label = 'Average Objective Time')
#plt.hlines(np.average(T),xmin = startRound,xmax = endRound,linestyle = ':',label = 'Average Anchor Time')
#plt.hlines(np.average(rT),xmin = startRound,xmax = endRound,color = '#deb500',linestyle = ':',label = 'Average Round Time')
for i in range(len(y)):
    if (winningTeamId[i] == defTeamId):
        if (spikePlant[i] != 'True'):
            plt.scatter(y[i],rT[i],color = 'green',s = 150,marker = '*', label = "Defender's Frag Win")
        else:
            plt.scatter(y[i],rT[i],color = 'green',s = 130,marker = 'o', label = "Defender's Objective Win")
    else:
        if (df2.spikePlant[i] != 'True'):
            plt.scatter(y[i],rT[i], color = 'red', s = 150, marker = '*', label = "Attacker's Frag Win")
        else:
            plt.scatter(y[i],rT[i], color = 'red', s = 130,marker = 'o', label = "Attacker's Objective Win")
    plt.annotate(round(aR[i],2), (y[i]-0.08, rT[i] + 2), size = 10)

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(),fontsize = '10',loc = 'lower right')

plt.title(f'{playerName} || Site Anchor Plot || {matchMap} || vs {opponentTeam} \n [Avg Anchor Ratio: {np.average(aR):.2f}]',size = 18)
plt.xlabel('Round number ->',size = 16)
plt.ylabel('Time [s] ->',size = 16)


plt.savefig(f'{playerName}.png',dpi = 600,bbox_inches = 'tight',facecolor = 'auto')
